# %% [markdown]
# Problem statement: To build a CNN based model which can accurately detect melanoma. Melanoma is a type of cancer that can be deadly if not detected early. It accounts for 75% of skin cancer deaths. A solution which can evaluate images and alert the dermatologists about the presence of melanoma has the potential to reduce a lot of manual effort needed in diagnosis.

# %% [markdown]
# ### Importing Skin Cancer Data
# #### To do: Take necessary actions to read the data

# %% [markdown]
# ### Importing all the important libraries

# %%
import pathlib
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os
import PIL
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential

# %%
## If you are using the data by mounting the google drive, use the following :
from google.colab import drive
drive.mount('/content/gdrive')

##Ref:https://towardsdatascience.com/downloading-datasets-into-google-drive-via-google-colab-bcb1b30b0166
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# This assignment uses a dataset of about 2357 images of skin cancer types. The dataset contains 9 sub-directories in each train and test subdirectories. The 9 sub-directories contains the images of 9 skin cancer types respectively.

# %%
# Defining the path for train and test images
## Todo: Update the paths of the train and test dataset
data_dir_train = pathlib.Path('/content/gdrive/MyDrive/cnn/skincancer/Train')
data_dir_test = pathlib.Path('/content/gdrive/MyDrive/cnn/skincancer/Test')

# %%
image_count_train = len(list(data_dir_train.glob('*/*.jpg')))
print(image_count_train)
image_count_test = len(list(data_dir_test.glob('*/*.jpg')))
print(image_count_test)
# Out:
# 2239
# 118

# %% [markdown]
# ### Load using keras.preprocessing
#
# Let's load these images off disk using the helpful image_dataset_from_directory utility.

# %% [markdown]
# ### Create a dataset
#
# Define some parameters for the loader:

# %%
batch_size = 32
img_height = 180
img_width = 180

# %% [markdown]
# Use 80% of the images for training, and 20% for validation.

# %%
## Write your train dataset here
## Note use seed=123 while creating your dataset using tf.keras.preprocessing.image_dataset_from_directory
## Note, make sure your resize your images to the size img_height*img_width, while writting the dataset
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
    data_dir_train,
    seed=123,
    validation_split= 0.2,
    subset= 'training',
    image_size=(img_height,img_width),
    batch_size = batch_size
)
# Out:
# Found 2239 files belonging to 9 classes.
# Using 1792 files for training.

# %%
## Write your validation dataset here
## Note use seed=123 while creating your dataset using tf.keras.preprocessing.image_dataset_from_directory
## Note, make sure your resize your images to the size img_height*img_width, while writting the dataset
val_ds = tf.keras.preprocessing.image_dataset_from_directory(
    data_dir_train,
    seed=123,
    validation_split= 0.2,
    subset= 'validation',
    image_size=(img_height,img_width),
    batch_size = batch_size
)
# Out:
# Found 2239 files belonging to 9 classes.
# Using 447 files for validation.

# %%
# List out all the classes of skin cancer and store them in a list. 
# You can find the class names in the class_names attribute on these datasets. 
# These correspond to the directory names in alphabetical order.
class_names = train_ds.class_names
print(class_names)
# Out:
# ['actinic keratosis', 'basal cell carcinoma', 'dermatofibroma', 'melanoma', 'nevus', 'pigmented benign keratosis', 'seborrheic keratosis', 'squamous cell carcinoma', 'vascular lesion']

# %% [markdown]
# ### Visualize the data
# #### Todo, create a code to visualize one instance of all the nine classes present in the dataset

# %%
import matplotlib.pyplot as plt

num_classes = 9

class_names = ['actinic keratosis', 'basal cell carcinoma', 'dermatofibroma', 'melanoma', 'nevus', 'pigmented benign keratosis', 'seborrheic keratosis', 'squamous cell carcinoma', 'vascular lesion']

plt.figure(figsize=(6, 6))
for images, labels in train_ds.take(1):
  for x in range(9):
    ax = plt.subplot(3, 3, x + 1)
    plt.imshow(images[x].numpy().astype("uint8"))
    plt.title(class_names[labels[x]])
    plt.axis("off")

# %% [markdown]
# The `image_batch` is a tensor of the shape `(32, 180, 180, 3)`. This is a batch of 32 images of shape `180x180x3` (the last dimension refers to color channels RGB). The `label_batch` is a tensor of the shape `(32,)`, these are corresponding labels to the 32 images.

# %% [markdown]
# `Dataset.cache()` keeps the images in memory after they're loaded off disk during the first epoch.
#
# `Dataset.prefetch()` overlaps data preprocessing and model execution while training.

# %%
AUTOTUNE = tf.data.experimental.AUTOTUNE
train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %% [markdown]
# ### Create the model
# #### Todo: Create a CNN model, which can accurately detect 9 classes present in the dataset. Use ```layers.experimental.preprocessing.Rescaling``` to normalize pixel values between (0,1). The RGB channel values are in the `[0, 255]` range. This is not ideal for a neural network. Here, it is good to standardize values to be in the `[0, 1]`

# %%
###  code goes here
model = Sequential([
  layers.experimental.preprocessing.Rescaling(1./255, input_shape=(img_height, img_width, 3)),
  layers.Conv2D(32, 5, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(32, 5, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(64, 5, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Flatten(),
  layers.Dense(128, activation='relu'),
  layers.Dense(num_classes, activation = "softmax")
])

# %% [markdown]
# ### Compile the model
# Choose an appropirate optimiser and loss function for model training

# %%
### Todo, choose an appropirate optimiser and loss function
model.compile(loss=tf.keras.losses.SparseCategoricalCrossentropy(),
              optimizer='adam',
              metrics=['accuracy'])

# %%
# View the summary of all layers
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling (Rescaling)       (None, 180, 180, 3)       0
#
#  conv2d (Conv2D)             (None, 180, 180, 32)      2432
#
#  max_pooling2d (MaxPooling2D  (None, 90, 90, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 90, 90, 32)        25632
#
#  max_pooling2d_1 (MaxPooling  (None, 45, 45, 32)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 45, 45, 64)        51264
#
#  max_pooling2d_2 (MaxPooling  (None, 22, 22, 64)       0
#  2D)
#
#  flatten (Flatten)           (None, 30976)             0
#
#  dense (Dense)               (None, 128)               3965056
#
#  dense_1 (Dense)             (None, 9)                 1161
#
# =================================================================
# Total params: 4,045,545
# Trainable params: 4,045,545
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Train the model

# %%
epochs = 20
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/20
# 56/56 [==============================] - 269s 1s/step - loss: 2.0249 - accuracy: 0.2517 - val_loss: 1.8662 - val_accuracy: 0.3221
# Epoch 2/20
# 56/56 [==============================] - 2s 39ms/step - loss: 1.7824 - accuracy: 0.3477 - val_loss: 1.6697 - val_accuracy: 0.4497
# Epoch 3/20
# 56/56 [==============================] - 2s 37ms/step - loss: 1.6829 - accuracy: 0.3895 - val_loss: 1.5678 - val_accuracy: 0.4609
# Epoch 4/20
# 56/56 [==============================] - 2s 37ms/step - loss: 1.5453 - accuracy: 0.4576 - val_loss: 1.5222 - val_accuracy: 0.4787
# Epoch 5/20
# 56/56 [==============================] - 2s 39ms/step - loss: 1.4945 - accuracy: 0.4794 - val_loss: 1.5736 - val_accuracy: 0.4631
# Epoch 6/20
# 56/56 [==============================] - 2s 39ms/step - loss: 1.3791 - accuracy: 0.5134 - val_loss: 1.4123 - val_accuracy: 0.5235
# Epoch 7/20
# 56/56 [==============================] - 2s 38ms/step - loss: 1.3599 - accuracy: 0.5112 - val_loss: 1.8720 - val_accuracy: 0.4564
# Epoch 8/20
# 56/56 [==============================] - 2s 38ms/step - loss: 1.4303 - accuracy: 0.4961 - val_loss: 1.5420 - val_accuracy: 0.4586
# Epoch 9/20
# 56/56 [==============================] - 2s 38ms/step - loss: 1.2989 - accuracy: 0.5458 - val_loss: 1.5153 - val_accuracy: 0.4944
# Epoch 10/20
# 56/56 [==============================] - 2s 38ms/step - loss: 1.2406 - accuracy: 0.5619 - val_loss: 1.4840 - val_accuracy: 0.5391
# Epoch 11/20
# 56/56 [==============================] - 2s 37ms/step - loss: 1.2024 - accuracy: 0.5686 - val_loss: 1.6297 - val_accuracy: 0.4430
# Epoch 12/20
# 56/56 [==============================] - 2s 37ms/step - loss: 1.2255 - accuracy: 0.5575 - val_loss: 1.5007 - val_accuracy: 0.4899
# Epoch 13/20
# 56/56 [==============================] - 2s 38ms/step - loss: 1.0930 - accuracy: 0.6094 - val_loss: 1.5407 - val_accuracy: 0.5257
# Epoch 14/20
# 56/56 [==============================] - 2s 38ms/step - loss: 1.0248 - accuracy: 0.6328 - val_loss: 1.5254 - val_accuracy: 0.5324
# Epoch 15/20
# 56/56 [==============================] - 2s 38ms/step - loss: 1.0095 - accuracy: 0.6378 - val_loss: 1.6163 - val_accuracy: 0.5503
# Epoch 16/20
# 56/56 [==============================] - 2s 38ms/step - loss: 0.8940 - accuracy: 0.6763 - val_loss: 1.8367 - val_accuracy: 0.5145
# Epoch 17/20
# 56/56 [==============================] - 2s 38ms/step - loss: 0.7992 - accuracy: 0.7115 - val_loss: 1.6265 - val_accuracy: 0.5347
# Epoch 18/20
# 56/56 [==============================] - 2s 38ms/step - loss: 0.7598 - accuracy: 0.7254 - val_loss: 2.2207 - val_accuracy: 0.4989
# Epoch 19/20
# 56/56 [==============================] - 2s 38ms/step - loss: 0.8758 - accuracy: 0.6847 - val_loss: 2.0025 - val_accuracy: 0.4922
# Epoch 20/20
# 56/56 [==============================] - 2s 38ms/step - loss: 0.6992 - accuracy: 0.7533 - val_loss: 2.1405 - val_accuracy: 0.5280

# %% [markdown]
# ### Visualizing training results

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# #### Todo: Write your findings after the model fit, see if there is an evidence of model overfit or underfit

# %% [markdown]
# ### Write your findings here

# %% [markdown]
# it is evident from the loss graph that model is overfitting
#
# Accuracy for epoch 20 is at 75% and validation accuracy is at 52.8% this is clear case of overfitting

# %%
# Todo, after you have analysed the model fit history for presence of underfit or overfit, choose an appropriate data augumentation strategy. 
# Your code goes here

data_augmentation = keras.Sequential([
                             layers.experimental.preprocessing.RandomFlip(mode="horizontal_and_vertical",input_shape=(img_height,img_width,3)),
                             layers.experimental.preprocessing.RandomRotation(0.2, fill_mode='reflect'),
                             layers.experimental.preprocessing.RandomZoom(height_factor=(0.2, 0.3), width_factor=(0.2, 0.3), fill_mode='reflect')
])

# %%
# Todo, visualize how your augmentation strategy works for one instance of training image.
# Your code goes here
plt.figure(figsize=(12, 12))
for images, labels in train_ds.take(1):
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(data_augmentation(images)[i].numpy().astype("uint8"))
        plt.title(class_names[labels[i]])
        plt.axis("off")

# %% [markdown]
# ### Todo:
# ### Create the model, compile and train the model

# %%
## You can use Dropout layer if there is an evidence of overfitting in your findings

## Your code goes here
model = Sequential([
  layers.experimental.preprocessing.Rescaling(1./255, input_shape=(img_height, img_width, 3)),
  layers.Conv2D(32, 5, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Dropout(0.25),
  layers.Conv2D(32, 5, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Dropout(0.25),
  layers.Conv2D(64, 5, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Dropout(0.25),
  layers.Flatten(),
  layers.Dense(128, activation='relu'),
  layers.Dense(num_classes, activation = "softmax")
])

# %% [markdown]
# ### Compiling the model

# %%
## Your code goes here
model.compile(loss=tf.keras.losses.SparseCategoricalCrossentropy(),
              optimizer='adam',
              metrics=['accuracy'])

# %% [markdown]
# ### Training the model

# %%
## Your code goes here, note: train your model for 20 epochs
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/20
# 56/56 [==============================] - 3s 44ms/step - loss: 2.2127 - accuracy: 0.1987 - val_loss: 2.1047 - val_accuracy: 0.2058
# Epoch 2/20
# 56/56 [==============================] - 2s 41ms/step - loss: 1.9717 - accuracy: 0.2673 - val_loss: 1.9398 - val_accuracy: 0.2796
# Epoch 3/20
# 56/56 [==============================] - 2s 40ms/step - loss: 1.7800 - accuracy: 0.3393 - val_loss: 1.7075 - val_accuracy: 0.4094
# Epoch 4/20
# 56/56 [==============================] - 2s 40ms/step - loss: 1.7117 - accuracy: 0.3811 - val_loss: 1.6255 - val_accuracy: 0.4385
# Epoch 5/20
# 56/56 [==============================] - 2s 40ms/step - loss: 1.6107 - accuracy: 0.4230 - val_loss: 1.5686 - val_accuracy: 0.4631
# Epoch 6/20
# 56/56 [==============================] - 2s 41ms/step - loss: 1.5836 - accuracy: 0.4263 - val_loss: 1.5821 - val_accuracy: 0.4698
# Epoch 7/20
# 56/56 [==============================] - 2s 41ms/step - loss: 1.5284 - accuracy: 0.4654 - val_loss: 1.5766 - val_accuracy: 0.4407
# Epoch 8/20
# 56/56 [==============================] - 2s 40ms/step - loss: 1.4924 - accuracy: 0.4754 - val_loss: 1.5351 - val_accuracy: 0.4676
# Epoch 9/20
# 56/56 [==============================] - 2s 41ms/step - loss: 1.4824 - accuracy: 0.4766 - val_loss: 1.5341 - val_accuracy: 0.4765
# Epoch 10/20
# 56/56 [==============================] - 2s 41ms/step - loss: 1.4109 - accuracy: 0.4994 - val_loss: 1.4510 - val_accuracy: 0.4855
# Epoch 11/20
# 56/56 [==============================] - 2s 41ms/step - loss: 1.3726 - accuracy: 0.5246 - val_loss: 1.5348 - val_accuracy: 0.4832
# Epoch 12/20
# 56/56 [==============================] - 2s 41ms/step - loss: 1.4486 - accuracy: 0.4972 - val_loss: 1.4616 - val_accuracy: 0.4855
# Epoch 13/20
# 56/56 [==============================] - 2s 41ms/step - loss: 1.3534 - accuracy: 0.5257 - val_loss: 1.5537 - val_accuracy: 0.4787
# Epoch 14/20
# 56/56 [==============================] - 2s 41ms/step - loss: 1.3085 - accuracy: 0.5290 - val_loss: 1.3624 - val_accuracy: 0.5257
# Epoch 15/20
# 56/56 [==============================] - 2s 41ms/step - loss: 1.2957 - accuracy: 0.5452 - val_loss: 1.3770 - val_accuracy: 0.5011
# Epoch 16/20
# 56/56 [==============================] - 2s 41ms/step - loss: 1.2747 - accuracy: 0.5491 - val_loss: 1.5514 - val_accuracy: 0.4497
# Epoch 17/20
# 56/56 [==============================] - 2s 41ms/step - loss: 1.2674 - accuracy: 0.5519 - val_loss: 1.3666 - val_accuracy: 0.5302
# Epoch 18/20
# 56/56 [==============================] - 2s 41ms/step - loss: 1.2035 - accuracy: 0.5748 - val_loss: 1.3713 - val_accuracy: 0.5190
# Epoch 19/20
# 56/56 [==============================] - 2s 41ms/step - loss: 1.1691 - accuracy: 0.5921 - val_loss: 1.4133 - val_accuracy: 0.4922
# Epoch 20/20
# 56/56 [==============================] - 2s 41ms/step - loss: 1.1430 - accuracy: 0.5977 - val_loss: 1.4000 - val_accuracy: 0.5347

# %% [markdown]
# ### Visualizing the results

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# #### Todo: Write your findings after the model fit, see if there is an evidence of model overfit or underfit. Do you think there is some improvement now as compared to the previous model run?

# %% [markdown]
# There is some improvement in model. overfitting able to be handled.

# %% [markdown]
# #### **Todo:** Find the distribution of classes in the training dataset.
# #### **Context:** Many times real life datasets can have class imbalance, one class can have proportionately higher number of samples compared to the others. Class imbalance can have a detrimental effect on the final model quality. Hence as a sanity check it becomes important to check what is the distribution of classes in the data.

# %%
## Your code goes here.
path_list=[]
lesion_list=[]
for i in class_names:
      
    for j in data_dir_train.glob(i+'/*.jpg'):
        path_list.append(str(j))
        lesion_list.append(i)
dataframe_dict_original = dict(zip(path_list, lesion_list))
original_df = pd.DataFrame(list(dataframe_dict_original.items()),columns = ['Path','Label'])
original_df
# Out:
#                                                    Path              Label
# 0     /content/gdrive/MyDrive/cnn/skincancer/Train/a...  actinic keratosis
# 1     /content/gdrive/MyDrive/cnn/skincancer/Train/a...  actinic keratosis
# 2     /content/gdrive/MyDrive/cnn/skincancer/Train/a...  actinic keratosis
# 3     /content/gdrive/MyDrive/cnn/skincancer/Train/a...  actinic keratosis
# 4     /content/gdrive/MyDrive/cnn/skincancer/Train/a...  actinic keratosis
# ...                                                 ...                ...
# 2234  /content/gdrive/MyDrive/cnn/skincancer/Train/v...    vascular lesion
# 2235  /content/gdrive/MyDrive/cnn/skincancer/Train/v...    vascular lesion
# 2236  /content/gdrive/MyDrive/cnn/skincancer/Train/v...    vascular lesion
# 2237  /content/gdrive/MyDrive/cnn/skincancer/Train/v...    vascular lesion
# 2238  /content/gdrive/MyDrive/cnn/skincancer/Train/v...    vascular lesion
#
# [2239 rows x 2 columns]

# %%
class_names
# Out:
# ['actinic keratosis',
#  'basal cell carcinoma',
#  'dermatofibroma',
#  'melanoma',
#  'nevus',
#  'pigmented benign keratosis',
#  'seborrheic keratosis',
#  'squamous cell carcinoma',
#  'vascular lesion']

# %%
count=[]
for i in class_names:
    count.append(len(list(data_dir_train.glob(i+'/*.jpg'))))
plt.figure(figsize=(30,6))
plt.bar(class_names,count)
# Out:
# <BarContainer object of 9 artists>

# %% [markdown]
# #### **Todo:** Write your findings here:
# #### - Which class has the least number of samples?
# #### **seborrheic Keratosis has.**
# #### - Which classes dominate the data in terms proportionate number of samples?
# #### **pigmented benign Keratosis dominates.**

# %% [markdown]
# #### **Todo:** Rectify the class imbalance
# #### **Context:** You can use a python package known as `Augmentor` (https://augmentor.readthedocs.io/en/master/) to add more samples across all classes so that none of the classes have very few samples.

# %%
# !pip install Augmentor
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: Augmentor in /usr/local/lib/python3.7/dist-packages (0.2.10)
# Requirement already satisfied: numpy>=1.11.0 in /usr/local/lib/python3.7/dist-packages (from Augmentor) (1.21.6)
# Requirement already satisfied: tqdm>=4.9.0 in /usr/local/lib/python3.7/dist-packages (from Augmentor) (4.64.1)
# Requirement already satisfied: Pillow>=5.2.0 in /usr/local/lib/python3.7/dist-packages (from Augmentor) (7.1.2)
# Requirement already satisfied: future>=0.16.0 in /usr/local/lib/python3.7/dist-packages (from Augmentor) (0.16.0)

# %% [markdown]
# To use `Augmentor`, the following general procedure is followed:
#
# 1. Instantiate a `Pipeline` object pointing to a directory containing your initial image data set.<br>
# 2. Define a number of operations to perform on this data set using your `Pipeline` object.<br>
# 3. Execute these operations by calling the `Pipeline’s` `sample()` method.

# %%
path_to_training_dataset="/content/gdrive/MyDrive/cnn/skincancer/Train/"
import Augmentor
for i in class_names:
    p = Augmentor.Pipeline(path_to_training_dataset + i)
    p.rotate(probability=0.7, max_left_rotation=10, max_right_rotation=10)
    p.sample(500) ## We are adding 500 samples per class to make sure that none of the classes are sparse.
# Out:
# Initialised with 114 image(s) found.
# Output directory set to /content/gdrive/MyDrive/cnn/skincancer/Train/actinic keratosis/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7FF2CFE17FD0>: 100%|██████████| 500/500 [00:17<00:00, 27.81 Samples/s]
# Initialised with 376 image(s) found.
# Output directory set to /content/gdrive/MyDrive/cnn/skincancer/Train/basal cell carcinoma/output.
# Processing <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=600x450 at 0x7FF2CFAB9C90>: 100%|██████████| 500/500 [00:17<00:00, 28.19 Samples/s]
# Initialised with 95 image(s) found.
# Output directory set to /content/gdrive/MyDrive/cnn/skincancer/Train/dermatofibroma/output.
# Processing <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=600x450 at 0x7FF2CFB41950>: 100%|██████████| 500/500 [00:18<00:00, 27.29 Samples/s]
# Initialised with 438 image(s) found.
# Output directory set to /content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output.
# Processing <PIL.Image.Image image mode=RGB size=1024x768 at 0x7FF2CFB71D10>: 100%|██████████| 500/500 [01:23<00:00,  6.00 Samples/s]
# Initialised with 357 image(s) found.
# Output directory set to /content/gdrive/MyDrive/cnn/skincancer/Train/nevus/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7FF2CEF74350>: 100%|██████████| 500/500 [01:24<00:00,  5.94 Samples/s]
# Initialised with 462 image(s) found.
# Output directory set to /content/gdrive/MyDrive/cnn/skincancer/Train/pigmented benign keratosis/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7FF34E881150>: 100%|██████████| 500/500 [00:18<00:00, 27.40 Samples/s]
# Initialised with 77 image(s) found.
# Output directory set to /content/gdrive/MyDrive/cnn/skincancer/Train/seborrheic keratosis/output.
# Processing <PIL.Image.Image image mode=RGB size=1024x768 at 0x7FF2E6403550>: 100%|██████████| 500/500 [00:40<00:00, 12.29 Samples/s]
# Initialised with 181 image(s) found.
# Output directory set to /content/gdrive/MyDrive/cnn/skincancer/Train/squamous cell carcinoma/output.
# Processing <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=600x450 at 0x7FF34CA0FDD0>: 100%|██████████| 500/500 [00:19<00:00, 25.34 Samples/s]
# Initialised with 139 image(s) found.
# Output directory set to /content/gdrive/MyDrive/cnn/skincancer/Train/vascular lesion/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7FF2E6486650>: 100%|██████████| 500/500 [00:17<00:00, 27.83 Samples/s]

# %% [markdown]
# Augmentor has stored the augmented images in the output sub-directory of each of the sub-directories of skin cancer types.. Lets take a look at total count of augmented images.

# %%
image_count_train = len(list(data_dir_train.glob('*/output/*.jpg')))
print(image_count_train)
# Out:
# 4500

# %% [markdown]
# ### Lets see the distribution of augmented data after adding new images to the original training data.

# %%
from glob import glob

path_list = [x for x in glob(os.path.join(data_dir_train, '*','output', '*.jpg'))]
path_list
# Out:
# ['/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0010034.jpg_77ce8300-7f43-4f94-b523-2c19b449ee27.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0010610.jpg_291b04e4-a797-4d07-836a-7c936abad824.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0010784.jpg_f45d2cc7-9008-4535-bfe3-546f3e00fc40.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0010478.jpg_069d90ab-bbce-4aac-aedd-90b50d0de778.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0000165.jpg_a699cc42-b6d4-49fb-a32f-d9d93a4ab726.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0000462.jpg_8093fd97-93fe-4469-9221-879093773803.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0010131.jpg_03aa8543-afa0-43ee-a486-52e031ad11d9.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0011135.jpg_dac211f9-392d-4070-b063-49bda37a6e5a.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0011012.jpg_60bd54ed-95b7-4148-976c-60751dc91bde.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0009927.jpg_acaa12eb-179a-4321-86da-1e9550c92a74.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0010441.jpg_f15dd1d7-7c04-4154-84a2-291910744a3c.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0010790.jpg_b60afafc-58c1-4dc7-b787-664aad28b616.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0010503.jpg_711768c4-c28e-4d69-bdb7-24e75de1d56f.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0010349.jpg_1889c7d0-352d-457d-bf19-b4f6fa3187e0.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0010852.jpg_44ec5fd0-0361-4af0-a1a3-638453613486.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0010322.jpg_17fdf0a8-a2c0-43cc-b7c7-e99608d4c803.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0009950.jpg_96dc08e0-bccd-4536-8c84-e6ae33d83f4f.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0000502.jpg_15a940df-4e8a-42eb-888b-23820987bfb4.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0009989.jpg_bbb211c2-c783-4279-9f30-cec27a968898.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0010372.jpg_a18c8ed0-6f56-4285-99ae-a5a3d78e2421.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0010056.jpg_ff823166-2269-4c1e-91cc-a5d0c2dc3758.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0010737.jpg_b94f08e8-868a-4ca0-9c6b-6e26d87391b5.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0009886.jpg_7495cce1-7783-4d2a-8f83-8a06d93e9114.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0000161.jpg_3d931714-3025-4fb8-871f-8b16c5b43079.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0000285.jpg_ed444f08-9b09-406f-9609-439931ae926a.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0010023.jpg_43dd310a-b8c4-4f6b-a734-d6ee31803358.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0010609.jpg_1d2fb3a6-34a5-49d5-a04a-e62c6925ab9a.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0000146.jpg_9a3ed75f-f175-456f-a4df-25716c646cd9.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0010938.jpg_dd264101-eb21-49f5-bbcc-143e5db3d852.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0000175.jpg_b3bb87e9-1478-4724-bfb3-002a89b4d95e.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0010081.jpg_80c48874-0dc1-46f9-8b93-9246bb00aa52.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0000289.jpg_4bced24b-da08-4c1c-b95d-7699f56fc979.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0010591.jpg_7e4d04bd-61d3-4641-b918-e7f3723a580b.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0011178.jpg_0493c423-3685-4fa3-8342-55170910ce48.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0010410.jpg_86270b47-77f9-4c6a-8b3e-7b5763b83bb4.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0010349.jpg_1531c221-ddbf-4c82-92b0-eb57e3b9804c.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0010466.jpg_8a86adb2-ca10-4998-8937-43e5423caeda.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0000526.jpg_c2f0fab7-cdc6-419d-9055-9f5d24764ce9.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0000296.jpg_0bab5c86-0469-4620-a599-61292416bebc.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0010772.jpg_f033864c-06f0-4155-9814-c27c62a6250e.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0010591.jpg_073959a1-ffbc-4d78-b5f1-b168e3b933ea.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0010576.jpg_718ded66-9bad-4831-ad6c-eab0c93dc2b4.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0010942.jpg_0a218c0e-5224-4ce3-8e63-b39b0d58121a.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0010778.jpg_aab55b26-1d73-43c1-8167-48a553d922a4.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0010319.jpg_077d7965-4dee-4db2-a3a0-a26aca294e37.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0010576.jpg_0d05b4c8-3dff-4584-a491-d838f3fced82.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0010965.jpg_f2fa64a6-3411-4a03-8b50-f26a550ee590.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0010415.jpg_b99a56c2-642a-4435-ae22-110a433a563f.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0000554.jpg_de52cfc8-f3e7-4c70-b70d-def4694caeb5.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0010866.jpg_af58f0e3-1be9-443f-b49d-26ebb84eef36.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0010162.jpg_0d4bedb9-e5e3-49c7-9d64-f85501f7878a.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0001127.jpg_5e1243f2-efd8-4c95-9c5e-4718bac8ed3d.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0010783.jpg_82d4e390-0765-4235-af47-9dc66f5a27ac.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0010746.jpg_f77a1d68-03c7-4c6b-b87c-7ccbfc834c1b.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0000154.jpg_aa4abb6d-e5e6-4a64-8559-c6c622b4aab7.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0001118.jpg_8ee48782-e496-4394-b06b-15dc64aea836.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0000141.jpg_5fab2405-0604-4197-a8c9-21161f410a03.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0010750.jpg_01146fa5-8a81-4400-815d-00b0b6f560c1.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0000293.jpg_7e6817a4-27b2-4553-8456-318157a6bbfa.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0010280.jpg_1c20e238-a394-41ff-9699-06a3d8bcd6b3.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0000450.jpg_c8ebc4a4-d753-4e28-9919-f076ff289d8e.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0011136.jpg_71a1d525-9528-4af5-a9d6-568283b2bae5.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0010313.jpg_4d4c33cb-0988-42bd-a85a-d4cd13de6d26.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0011163.jpg_dc7b7a90-fcce-4014-98d5-7dbe203b7c35.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0000291.jpg_182fab07-c53f-4804-9fc4-2ecb2de339a0.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0000141.jpg_e6d6f6e8-21b2-4f70-bd0c-2d18a6ce8f1e.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0010543.jpg_4b5428e2-531a-45e8-b793-1b5d55df9b07.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0010407.jpg_8c22adc3-1884-4a40-9f15-0c3ba814c253.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0000297.jpg_eecc9931-1530-4fad-a83e-a1c0bb55597f.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0011099.jpg_0302ffcd-85fe-47a0-b44e-3ff8aa11efff.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0010174.jpg_8f82229c-6373-4400-a62e-c8ab38b4aeb8.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0009984.jpg_89b9615c-cc52-4bbb-9b81-6d75f9e8636c.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0010414.jpg_dd0e8de5-0250-4f80-8c33-3c418abceb6e.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0000412.jpg_603e1ab4-43d6-4739-a80a-84d705b3ed03.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0011185.jpg_013412ff-09fe-4198-8efc-b98e5468a419.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0000173.jpg_a1117c78-bd7d-4442-a048-685c9f8e3b05.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0001134.jpg_4ae0ead0-ab47-4184-b029-a44be3d00a20.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0010741.jpg_1098a7f4-a4d6-4bea-8f93-389883596001.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0010393.jpg_850a874c-2101-45a6-87c4-fe67a154f2dc.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0000294.jpg_146c36f2-700f-434f-9013-423e3783c1a2.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0000152.jpg_51942d70-3289-45c4-b2f8-22b64b444a67.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0000164.jpg_956c6539-b444-4782-9df8-b8174476ad99.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0001135.jpg_e2286707-6f83-49b4-a555-718e1b45ad18.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0009886.jpg_f162372d-2416-489f-b392-2309cac2910d.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0010866.jpg_99153e2d-17ec-4f75-9eee-da9dc30d304b.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0000167.jpg_e092ab77-c107-4c9b-824e-73b591f358ab.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0010024.jpg_d1b1090b-6a19-4068-85e3-7f85ca75af27.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0000440.jpg_31af434f-07a8-428f-a0b8-edea3c46e957.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0000304.jpg_2fc0d8e1-ea29-457a-89b5-2d301c51c71d.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0000153.jpg_4af13acd-8590-4caf-b5e6-0af707c21705.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0000149.jpg_4e04d22d-4755-41a1-ab27-528322caa7ca.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0010137.jpg_64756a13-551e-4f61-836e-1f06b7146b42.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0000531.jpg_6a806404-7a03-475f-92e1-79e27fbad43a.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0000446.jpg_157dd3d2-ea33-4172-881c-7f972c644d87.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0010469.jpg_7f4e6d91-5a0b-47ac-aa6e-b8b7e335aff7.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0001106.jpg_f06dac69-b4b6-44cc-8e9d-da9d9b6b5107.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0009971.jpg_cbcf4e1a-f084-4f6b-a146-8b581d0600c1.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0010993.jpg_4cb0e0a5-effd-4de1-9f19-34d438a02e96.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0000432.jpg_6d9aeb1c-1bc0-434a-89eb-0e514598432b.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0000153.jpg_e847e107-e5e7-4a31-9cb3-559770248bf0.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0010872.jpg_405860b3-979c-4c74-b51b-4c13ad442ee0.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0010990.jpg_1ed5d3cb-de56-4c26-aab8-6aa526c83792.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0010782.jpg_430507c2-2a06-49fb-be1d-4b235d4a7255.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0011095.jpg_029a14a1-d0c5-40b8-9a38-7e41ad8a0294.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0010295.jpg_81fa8d5f-7ff3-427d-bd0e-11fecea31216.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0000149.jpg_63ef2d39-4c72-4bb1-a366-dc4b8b1dbc75.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0000139.jpg_45fe7b93-0afb-4d56-9f90-d019ebe88c3b.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0000502.jpg_a4e87e21-597d-4339-aec7-fbba8c4d6e03.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0010729.jpg_7fef58f6-81b2-4d03-b5a6-3ee8692ddb93.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0010241.jpg_efd4cf30-513c-4b27-ba72-c7d6ee7660bf.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0010413.jpg_d578dc8a-0687-43b8-afdf-6a7b7fd4f6a6.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0010039.jpg_e93f02a8-f82d-4388-ae93-71da23b99b98.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0010809.jpg_63bbe443-0355-418a-8c98-2b8afe86246b.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0000153.jpg_a4a11ba6-3a2d-4e8a-ad37-bf08a1d989f1.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0001138.jpg_4cb15f82-7d33-48db-b07b-266593fdc192.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0010208.jpg_382314b7-9d4e-430e-834c-d348dc05d0bb.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0000148.jpg_fd4335c6-a0cf-4ed6-9f41-85911a515e7b.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0010729.jpg_8c62284e-ae91-431d-be09-9bcf4546f5f7.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0011176.jpg_03ff38f4-ca64-4ca3-ade2-ad65305f236c.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0010245.jpg_3218c5dd-bd98-4c4e-856d-220012841916.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0010728.jpg_29d20585-871e-4641-a95f-f9b02f1b2a58.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0011139.jpg_8446980c-7605-4051-a35a-741735e1d524.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0000156.jpg_99e18e39-379f-4227-9a1b-536776ad552d.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0010426.jpg_0e4ad052-34f9-4915-a127-e8afe786086f.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0000521.jpg_8ec59741-04bd-4b55-8bfe-fc24e8490e91.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0010596.jpg_c001d991-55d0-4d95-b3e6-2edf3e10a131.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0011181.jpg_e67a1d89-9c5f-4f2b-8b51-160fba05a43d.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0010225.jpg_06c7235b-5b51-4043-93c9-5175b3215426.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0011174.jpg_808c1afc-0982-4b4e-8c5e-8a2b814b9aa2.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0010729.jpg_a14e4a81-6411-472d-988c-781dccda3adc.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0010982.jpg_778a1294-04be-4ad6-950b-bc26ef7d8e23.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0011057.jpg_b819b433-fd67-4474-9703-fad9800e47ef.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0009918.jpg_128735eb-6bcc-48e8-80a8-5b169627bde2.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0010391.jpg_1e7c8202-699f-4ce5-a045-0cfdd3776eb8.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0010036.jpg_f0a0d140-a38f-49ec-8765-c7625f9abf28.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0010469.jpg_03532f43-17aa-4580-821f-57e39631e075.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0010534.jpg_4c3b4c62-2623-4a64-8035-25c94726cc22.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0010852.jpg_25a19451-d11d-404a-8e2c-8d196ff58304.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0010175.jpg_2fdf209a-f5a3-4274-bfd8-c903b196d837.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0010164.jpg_48677539-01b4-4a02-8349-ee3a863ddb43.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0010283.jpg_1a106c6f-be3f-40a6-8e1b-def9bbf00f6e.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0010609.jpg_eb15cb28-4ca8-4b42-ad6e-c0bff18bec71.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0001143.jpg_e0991002-33d3-449a-8b08-823d0ef0a2aa.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0010631.jpg_25506068-af27-403d-87d6-41f845cec601.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0000296.jpg_8ae2c0b3-19fa-49e4-88c4-9c61ed6ea15b.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0000520.jpg_3aa99cbd-911f-42d3-ab77-0da1a8407f10.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0010548.jpg_9bdb03ff-f094-4479-a64c-386cf55c7603.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0010478.jpg_6165f043-0e1f-45c0-aaf7-39ed8a289648.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0001128.jpg_d9bedc2f-336b-46a9-9d48-213d889cf190.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0010394.jpg_125da712-32e0-47fb-9c1a-e93c50398639.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0000303.jpg_5414cbc8-e125-4233-bff9-d86b3e7584c8.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0010909.jpg_39ae6fd1-9ac3-4d68-bab9-cd2e867a92b3.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0000484.jpg_7f4afd69-467f-484b-b412-0aba13e3d3b8.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0010391.jpg_18696538-a3ff-4afa-9f2f-997379e43c27.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0010559.jpg_09ccf0f6-87fe-46e2-8494-30147667b8f2.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0010580.jpg_b781cede-c4a6-43d0-bd76-d8972d029a74.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0010909.jpg_a2f4c8ed-95f6-4f4d-896a-f319b89129f6.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0001142.jpg_7b2ec0e0-1010-4998-b3cd-08863d7bde60.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0009960.jpg_2dd8889b-407e-4812-9b16-418f41d148ff.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0011161.jpg_5bcddfef-c365-4094-babf-7b0c9074226d.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0009897.jpg_565f6b6a-9516-480b-b8f0-e56a61a1e455.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0000304.jpg_4398032a-cca9-4acc-a500-569b19d0b50a.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0009913.jpg_14ea0859-0d4c-4b47-be64-cc417d9597bc.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0000292.jpg_74463272-3d46-4fcf-9c7c-d6c98e3742e4.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0011185.jpg_669d2de7-16d9-4cef-983f-b01114568a55.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0010965.jpg_9a81e137-627a-44f0-82d6-a64f2fcd4a02.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0000176.jpg_dbcf179d-6381-4371-8f81-7bd3ee268f4f.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0009934.jpg_1af76e64-672e-4c35-8bf2-b5331f4493cf.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0000399.jpg_e5a3c851-0a34-4b39-8570-1a4d56d64bbb.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0010245.jpg_6c8cfb5e-539e-4ca2-a7a2-f3d5b5f0fa6b.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0000466.jpg_7979fca9-26f8-4645-be93-8a1d2ec80577.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0000417.jpg_f021a5d1-3148-412b-8bbb-6309615b4de5.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0000551.jpg_d1cfde3b-2509-4ac8-8f88-eba58a79a068.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0010175.jpg_08d769c8-faa8-418e-be9e-e448d872bdd2.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0000294.jpg_f5253aec-bd42-4822-8a4c-92881cf3fadf.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0000159.jpg_19278323-a50b-4a33-a9e5-d4a1122271ce.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0010289.jpg_d314d900-18ee-4b4c-b34d-486480161350.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0010746.jpg_032997f7-bedb-4b80-b8bf-7b7de617114c.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0000166.jpg_da23f6e2-5146-45fe-8444-be9b9ab62bd0.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0000306.jpg_55727bd9-303e-4237-831b-47813cc26d76.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0000162.jpg_41847c93-8dc5-40a3-a5ba-bb54a2feeddc.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0001124.jpg_fef15dad-400f-49d9-b92d-35581b839f0b.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0000169.jpg_89040ecd-c12f-4386-9627-4bf60e68f4d8.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0009918.jpg_eaf21954-ca5e-4770-9f05-82e2fa5b858b.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0010036.jpg_83b22e50-301d-4f72-9f02-714be5e9fa47.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0010782.jpg_feb83f34-91b0-4264-9cce-d936766fd405.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0009868.jpg_4afca6cd-acae-4cdb-9325-15cd91afdf87.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0010271.jpg_59833477-e037-4232-8e57-f00d965e2f29.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0010580.jpg_04cf6c05-2d7b-4c87-9412-375ca4542062.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0010663.jpg_ce981715-0fd1-4825-b4d8-15172e1fdd20.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0000502.jpg_f1c97ebe-75bd-4363-b7a7-db2eb67208e7.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0000160.jpg_3eec0da2-09ab-4a04-b8a6-cdbb0a5fec98.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0010925.jpg_a01ea88d-8735-4a75-b4e4-ad34a166fc57.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0010148.jpg_902d771c-975e-4eeb-8e31-6fc20f6f4a90.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0010391.jpg_eeab196b-d7c6-4cce-af11-85b77a73ba7a.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0011193.jpg_4c69e0ae-1ccc-4811-80db-3cec6df46c98.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0011043.jpg_1d40093a-4b06-4f65-ad8d-21aa49e0917b.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0009910.jpg_c6bae026-7c89-47a4-9884-12ce8ba769f2.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0010550.jpg_ce2c439f-28a8-498f-aba1-4e52ba90abe4.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0011193.jpg_18a11891-adb4-4f03-aa56-54adb26b0187.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0000294.jpg_acf43ea2-c256-43bf-a9cc-7b64e2475c6c.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0011169.jpg_c449d6a2-c60b-4fcc-9e19-5ab7470ceb32.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0010579.jpg_8df66930-f110-4540-ba84-3e23fc4c42b1.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0011039.jpg_1ba6bc80-f75f-488d-811c-d4e09fd7f2f3.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0011043.jpg_223d3d97-fcbd-41bd-9959-12a1fd96ecc1.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0010900.jpg_5c408fd6-7059-4114-a1d2-e1ac913e72ee.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0010564.jpg_f0baab10-f682-427f-8bb5-34d670a73f93.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0000434.jpg_1a19e2f2-745a-4f54-9a65-cf0a2b380635.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0010503.jpg_6e84e87d-1156-44c8-86b5-f1f02f34835e.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0000412.jpg_e85fdef1-f8d0-4f37-9de0-d419d948294a.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0010067.jpg_17030fb7-9548-47e5-aa13-25ec7ad8a039.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0010349.jpg_03794f09-24c6-4c81-8767-244aac28633a.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0009916.jpg_6850a347-848c-4764-ad94-d0938c4a2075.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0010791.jpg_5e5a29e8-0495-4356-be21-c8657bd94a9e.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0010397.jpg_57c369b9-144e-4848-8621-68a792a9b7dd.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0011178.jpg_ba072583-c078-49b8-8f03-a95c88d5be2b.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0010583.jpg_fda3d92c-2b7f-4c58-80dc-ce10687028c9.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0011007.jpg_245dfc34-1447-4342-9904-eee948e3afd5.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0000393.jpg_1d81ab2e-ae76-4d4f-8223-9618f8594114.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0010765.jpg_f4c8983a-3c6b-4b15-af8a-02d09c28cca7.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0010432.jpg_96849dcf-8a31-4cd6-ab0e-e0a4641099f9.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0010119.jpg_abc737f6-e2e8-414b-9190-9d91f057bf1e.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0010979.jpg_1d37aabe-da48-422a-9a17-fa8d1d6f25e0.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0000291.jpg_bbabb8a5-a93b-4ae1-a7ed-fa9f840e4324.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0000446.jpg_18ab42ad-80ec-4f88-b1df-443474dee730.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0000149.jpg_4182101b-81af-44f0-a4f0-40c7778a758a.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0010803.jpg_1bf40327-9a91-43c7-9690-ab35e95eb9e8.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0010770.jpg_12fd9b69-67c6-4db3-b968-5043c87a5037.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0010364.jpg_db74d9ca-1d24-412f-b4d4-561c51b9b96e.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0010385.jpg_54db6bcf-7b30-4030-bbb4-c2e9507ce20f.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0011121.jpg_d70cbb04-8b6b-4756-985e-e7617243b6f2.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0009913.jpg_80d65bbb-c4e5-49de-8214-adbab65324d4.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0000306.jpg_5b03e62d-8c19-40a1-a739-00c7646765e2.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0000297.jpg_62d0a2fa-f866-49dd-b918-7fd7b1de9bf7.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0009916.jpg_8f752b21-a74c-47eb-9ac0-5b255c1fe20b.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0000553.jpg_20ed5403-3fb1-4ed8-89da-bd9874fea0f3.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0010872.jpg_d0021334-83b3-4b01-b8c9-5080ccf85926.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0000553.jpg_0b7e9388-f582-4868-94e3-73a4ec6ad939.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0001127.jpg_9946c94e-ecc1-4130-9a6c-4580b45a5ce5.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0010862.jpg_c9602ebc-2481-4080-84c5-e4b4163f8a48.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0010106.jpg_325c3b17-c7ea-4576-ba8f-43d9e28728c1.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0010750.jpg_019f1232-fe8e-4764-9f11-0633c912ce3f.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0000311.jpg_9eae581f-ef6e-4f7d-b2d1-baf9951658d5.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0000153.jpg_b97cb807-340c-4084-a28b-ca0ed937045b.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0010468.jpg_75c72fc8-99f5-44f4-897d-7f129380f019.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0000394.jpg_0a6718cc-a4bf-4b97-91d4-d660562df3ce.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0000428.jpg_72dba68a-494c-4be4-bdcf-1fdaab15d148.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0000299.jpg_6ac51e8b-afcc-453f-a7d8-0b7b6b478a75.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0010271.jpg_ddc278c5-aa73-4750-ba5a-1f972f790746.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0000285.jpg_a12846e0-d60b-4d22-a28d-426f46266e10.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0000521.jpg_d389f3ed-c18c-4adb-be63-9813a9e9e8df.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0000398.jpg_ea765efb-7544-459a-843e-21aa074ab490.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0000292.jpg_24d146af-0570-46b7-8a16-94c82f627ff8.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0011136.jpg_1205f0ad-c8e8-463f-bb32-4fce99cbcd42.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0010162.jpg_22d874c1-dc07-4e8f-a5a7-1367f305d38c.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0000175.jpg_33e71fa2-97aa-41a2-a18e-a26207319550.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0000531.jpg_e683c3fb-7a6f-422b-ae55-80ba8bd0ea7a.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0010140.jpg_37c27fa4-0efb-4d66-83e0-b8eb883657c0.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0010765.jpg_05c095a9-f538-4c1f-8811-7826f33fe230.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0000469.jpg_58b415e1-5ab3-4d73-a788-60979110ab29.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0011187.jpg_da7a3c26-502f-43c2-b178-d4e6877e697e.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0011176.jpg_64ff4941-e8dd-442e-b64c-767fb274171b.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0010917.jpg_ae74e140-08bb-4243-847d-187b7b370880.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0010551.jpg_b36057de-9c7e-425a-a6b3-a0b40b4bc492.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0010596.jpg_3703bdc2-a69c-46aa-a55d-dd5ef7df3718.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0011032.jpg_eeeabdb6-1449-47ba-994a-f57da92215db.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0010359.jpg_c6236001-a999-42f6-916e-21e197afaef3.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0010551.jpg_f722a0da-6412-4c58-9516-d00387b62f36.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0010777.jpg_f2e369b5-c63f-43bf-bd6e-e8921fb26ede.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0010313.jpg_659dca4b-bbc9-4879-8f24-39939944db6c.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0010241.jpg_bc7de11c-2b29-4371-96d1-cf7e77d45bae.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0010023.jpg_0501a116-14d7-430a-b2eb-99e793f8f92f.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0011012.jpg_d854a6c6-b7d4-457d-834b-8b962165de97.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0000171.jpg_0a2d3e87-78f9-4735-b344-a9d0d213dd6f.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0000288.jpg_4e9d1f96-078d-4290-b157-9aafa6c4bf79.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0010778.jpg_157ef132-71e1-4d93-9afc-1c12374451f5.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0010990.jpg_427a98a3-1a44-4b62-9799-bd87cabc369f.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0011042.jpg_e741238a-71ad-4b77-b003-19a1ceb862e8.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0010784.jpg_7bce17cf-765c-4409-beb3-ed3fd3d0bf59.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0010759.jpg_e4f5870e-5cb5-4ca4-bc79-100941a70a60.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0010359.jpg_208d44cf-7ee8-429b-9bbe-ac7e020ba6b8.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0000175.jpg_6f704cf5-6b6e-4b47-ac69-c43bf1438c05.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0010707.jpg_14cac9a0-4db0-44cf-b12a-3c5410ce50fc.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0010878.jpg_cb82b9b3-55e1-4688-a8c4-72f830fedbfd.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0000444.jpg_efc4fcb5-6f96-4028-9d37-4d5d16b2414a.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0000513.jpg_2f18db29-99bd-4e96-be8f-eaa72dc0089b.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0000162.jpg_c7feec55-7620-48a0-a6cd-d0e324b370ee.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0009916.jpg_0a3d5882-962b-44f6-a60c-05c4e8c718a7.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0010140.jpg_fee337f5-71b4-431d-b433-7d65ee4cd0d3.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0000398.jpg_2be091b1-098d-4294-8ee5-62e7f5f128b3.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0010023.jpg_2548956e-16c7-4dd0-a9d9-ea7413d73744.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0010299.jpg_a78077bc-ddc5-4b3b-a321-83300eab78d9.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0010532.jpg_12958cf9-2cfd-4e80-8ef9-481add97398d.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0000466.jpg_dd49217b-59e6-4f06-8b38-8d428ab31ec8.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0000554.jpg_6af21f90-7ce3-46af-88cd-077325a92b56.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0000311.jpg_c7dd7d4d-65e1-41c1-9a4f-7235d7bf2fa7.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0010883.jpg_44bd3094-9c4c-4aa6-8b34-d340ecad6241.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0010119.jpg_ef5e48a4-0475-4cfb-b878-e2b1b89a1210.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0010872.jpg_f3e4a1c7-b563-42ea-8e56-22b9ac8636d4.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0011161.jpg_13da674e-eb6f-487d-9154-f529f21d6a6f.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0001152.jpg_7cada230-72aa-4f90-8da7-0428c44fd29d.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0010174.jpg_8702d083-9ae2-4ad0-8fb8-7392d734acd3.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0010189.jpg_e62bf3f5-39da-421f-bd95-1192df5029b7.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0000484.jpg_83ce2bb2-7b70-4eb9-8ebd-97c7eded9bc2.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0010777.jpg_4a4c855d-5e9b-4570-ba7f-d106de1d214e.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0010402.jpg_62e62e0f-bbee-4b25-9827-52013dc144bb.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0010119.jpg_f5f1a628-7128-49b4-a8e0-0814a2c50032.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0001103.jpg_6d85aeae-54c2-4882-b705-2fbf43945674.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0001101.jpg_0a81ccfd-c9e8-486e-a89a-249f0b49bc09.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0010029.jpg_00bb291c-57ad-408f-8ff3-9fd084e98835.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0000400.jpg_60190615-ecb1-4d5e-adf7-c1dbd04e2ea5.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0000145.jpg_3ac07a75-c659-4015-ba65-ab72d46d505e.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0010934.jpg_a9d94205-958e-4a99-ab45-5e774f134576.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0009916.jpg_5f6a0d30-cb8d-4d61-aa97-82404ef45a94.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0010912.jpg_7caf2e58-ffb7-4c56-9e3a-074179bc7963.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0000155.jpg_71e1dcb2-fee1-4052-b63a-d000f5537329.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0000306.jpg_a4ba5b5f-92c4-4f60-b761-8e5c3e8a819a.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0011032.jpg_51d66315-2e4b-4f25-9c54-ba24f2114853.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0010834.jpg_1a9201ea-07d0-4919-96b9-48e122202ecb.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0011163.jpg_e1ea6f16-41e4-41f6-8e90-7fa6e0f72645.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0000141.jpg_e42bcaa8-fdf4-4187-baea-d854d08ced07.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0000466.jpg_315eb730-9150-4b86-8ca5-c92419aced58.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0010385.jpg_9912dbd6-a033-4155-a0bd-71142d4fe2b0.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0010909.jpg_a46670ac-8db5-4d3b-a00e-bbfe9faec44f.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0010364.jpg_0ca07796-a9b3-4784-8ede-410d62c119d9.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0010648.jpg_bfada9e7-dc0b-44e3-9b06-51fc26f15528.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0010583.jpg_2ee219d1-6f74-4830-ac8e-0d00dbfd70a7.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0000531.jpg_32fd6ac0-8470-4cf6-bb8a-b8d8354f0b4a.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0010466.jpg_6ef524e8-3958-456f-9888-7c3e2ef5987c.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0000143.jpg_dddc123e-0f2e-40f5-bc01-f6ade84ea0f9.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0000405.jpg_123ef04c-c71c-48a0-90a8-16d17292ac54.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0010376.jpg_0ccfd579-cba8-45c9-af88-a5475e19605a.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0010050.jpg_a0c4c4bd-e74f-4925-b751-85ef6c9aa70d.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0009916.jpg_0bf8e753-f226-4816-98f0-320792fc91f9.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0010137.jpg_696073d9-0026-4adf-8159-120dc0d99c9f.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0010728.jpg_c57d8169-c26e-424b-bf43-0c1cba9dea25.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0010016.jpg_79c6678d-10e4-4c49-beae-b984ff350a32.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0000298.jpg_f78055ec-06e1-4c0a-845b-94d7d6da9028.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0000548.jpg_0303689a-abca-4daa-b98e-2b52a967e2ce.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/melanoma/output/melanoma_original_ISIC_0000160.jpg_d78eec62-f60d-44d2-b328-6c472b2d1109.jpg',
# ...
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0027239.jpg_e6b2c995-f51a-4165-9a7f-4136fd88e91f.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0028473.jpg_5f06f3c1-615a-4c10-bfc7-bba41e64ee87.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0027710.jpg_a40672d9-f5ba-4a75-9e94-df07e7ceee2e.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0028165.jpg_723dbbbf-0f98-4151-9aee-17bf0b640ffe.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0024758.jpg_19eb2e16-2c46-48dd-8507-5916c8b8e504.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0026153.jpg_e7d5c02c-a749-42bf-a89f-97b74fcdc4d1.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0027737.jpg_e617550b-6d8c-47d1-bbfa-b6c4ea35d149.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0027454.jpg_d49b6876-35e1-4638-b3e5-36b326ca843f.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0027747.jpg_fee75cfd-9bb0-43a3-ac26-6bfe4e12c9aa.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0024676.jpg_74e3a050-32ff-44ac-a09e-8900e9b7bb45.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0026849.jpg_938906bf-6ffa-4c1c-80c8-77e0784b186e.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0026566.jpg_578bfc57-021b-43e8-a1f9-8d2fb41b2e86.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0026790.jpg_4a1bec20-087b-499c-bfc6-4f3e77629c19.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0027780.jpg_87d2b175-6e2f-48b6-a46a-c4824e74335c.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0026769.jpg_820997f7-1b58-4f0d-98c6-5d5979c08c19.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0025529.jpg_7297641f-7af4-48c0-865d-babd4646148e.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0027023.jpg_e4958da6-dd55-42cd-b694-f6ee83ba9587.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0025781.jpg_7ef75476-ab0b-489c-81c1-e186c2a5d756.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0025510.jpg_e609e4d0-3097-4d44-8cf7-037d00be6574.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0027335.jpg_de947475-563e-4eb0-a517-876b6f082a86.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0028124.jpg_f831f592-91cc-4940-83f1-cc6998b4b9c8.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0028503.jpg_f88860ef-52ba-400c-b7db-154ba1c45c94.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0026524.jpg_97215922-cc3e-423b-989b-63b942798325.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0028560.jpg_4c13b4c2-662a-47ce-9d1c-6c878d71e425.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0024910.jpg_9355827f-dce1-4dba-b9f2-9a0d2984b698.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0026827.jpg_e94098b4-ff99-42fe-b770-fa9e4ac98af0.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0027006.jpg_58c97280-284d-4c09-82a7-cf3c6af83a88.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0026835.jpg_1dca45bc-4279-4a9b-8179-44e989defcb1.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0027584.jpg_b4a6b8d6-e7e3-4241-b5d0-c43eb8b23efd.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0026265.jpg_af3895e3-92ff-48dd-a025-7e62f3848c68.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0026514.jpg_1d49143d-ea6e-455b-a40c-3020482d9a4e.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0025086.jpg_49414a30-bd29-4d47-b38b-ea0c828cd373.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0028490.jpg_89f2c15c-c0f1-4744-a886-b7067fdb77a4.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0027275.jpg_285f7e7b-cef0-4884-a913-dd4745264c29.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0028404.jpg_53cf2149-df47-4875-9996-b29a049a331f.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0024505.jpg_24af23a6-41db-469b-9ec0-46244ddadb71.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0028496.jpg_e1f69d68-7736-4acf-a2be-bfcf9eb6a88a.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0026135.jpg_8d8d3c78-e13f-4c38-8cd0-083fea93f622.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0026276.jpg_4ce9403d-1171-4156-94ea-5afea1a4a715.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0025703.jpg_370db6fe-e198-47a7-95ef-a6847c32419f.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0025083.jpg_012057cf-38fc-40bf-bc07-c1d8b5f21c8a.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0025030.jpg_60fca675-6279-4fee-8d95-92e8a48afa2d.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0025781.jpg_cb7350ac-490f-4a35-8db0-8e61119bd2a4.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0024851.jpg_74d011e6-b704-44e2-937d-c45d55d3195e.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0028640.jpg_26b1b27e-d2d3-458f-8c5a-d36f4c27e426.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0028560.jpg_df5bf538-b31a-4e84-aeaf-088643548c71.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0028404.jpg_bd5f9504-8c29-4da1-8ff3-0d9d95872643.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0027953.jpg_0dde111d-91e1-4793-9a00-fc8d57002181.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0024489.jpg_6a92c245-2697-4d9e-acee-5da15c878c3f.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0026493.jpg_d164f853-b6d1-443e-a15e-1a08b4c0ca4b.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0026679.jpg_9f171cc5-1852-4195-bea8-db11eee526b2.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0026959.jpg_0fe9edb9-df8b-4cc9-a8ab-4d314132f66c.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0024943.jpg_35b7445c-01c3-4b6c-a43d-eb5b43ff9d03.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0026846.jpg_7990e5f1-d729-4883-b27e-5178a5f13c28.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0028223.jpg_b0f0720c-f57b-40a5-b519-749266995558.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0025656.jpg_09191afc-52a6-43f4-bda5-9b1cffb7651a.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0027053.jpg_98566bdc-ac4a-44af-8f1e-4c3da6fa12cd.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0024825.jpg_60f3b6ea-c4fb-4869-bad3-e4d811b93417.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0025804.jpg_57526b90-a241-4d0f-a151-da028020bd0c.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0025040.jpg_59f072ab-a327-4f6a-92e3-92a3f94e3890.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0028646.jpg_c78b5fd8-c010-4f9a-909e-445b26798150.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0024782.jpg_ef301619-ecd5-46cc-ade5-c9b50a5fedbb.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0027064.jpg_b044401d-1380-44e8-8fbf-42da0b6df554.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0027649.jpg_b05dcbea-50bf-4410-880f-254f61d7a6df.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0025330.jpg_2e90f860-1e26-43d2-97f8-378905f5d1cd.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0028587.jpg_ad84241b-160d-465a-9f82-43c090a16e67.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0026728.jpg_8ee81b37-8efe-49c3-81f1-63608c80ac97.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0025885.jpg_0f98c03b-228e-43a4-87e2-9732008bb145.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0025838.jpg_79ccf7d0-7dc9-43f3-8d2d-f6319a193425.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0026790.jpg_3213fb58-565e-401d-b25c-656cdc771af0.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0024740.jpg_78c768f8-7122-408d-a8b4-7eca2537cb3c.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0026787.jpg_faa4e65c-af5a-45cb-8b22-8deacc54a2ca.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0027820.jpg_19a11f63-8c42-44b7-8abc-fc41801a5ecd.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0028121.jpg_5a3700ca-5d7a-411b-a88a-57d5464606c9.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0025874.jpg_2d71b40d-428d-4660-80ec-1249afe9c2b9.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0025837.jpg_62aae949-5d0d-4a40-9372-07688e8e8c23.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0027094.jpg_4ac369af-f88c-432b-9097-8a529ff2a4cc.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0025703.jpg_bbc418e1-2b87-4b84-a7fb-d0312899ce8b.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0028354.jpg_9571df16-dc5d-48cb-808b-876bd31e00b7.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0027374.jpg_e5fca56d-4a9a-4cb0-a799-e107dd9dbacc.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0024772.jpg_a4eb0af0-95d8-4ed0-9d38-84644f35794e.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0025297.jpg_a9eb3926-31e6-4964-85da-e0f90b6041ae.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0026614.jpg_2fb84418-a2c6-4d85-8fcd-77052988d02c.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0025937.jpg_5c6f0574-1240-4101-a578-3e1423222484.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0028100.jpg_66bb35c6-f79c-4959-950b-f117fd8570e8.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0026867.jpg_4a908950-39e5-45f2-ae43-148e749f8959.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0027139.jpg_68428e85-3fda-48e0-ac8f-341d8ccd3050.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0027893.jpg_707afe7e-488d-4d37-8405-42d6d5eb176b.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0027374.jpg_35656747-f48e-473f-917c-452018c5952f.jpg',
#  '/content/gdrive/MyDrive/cnn/skincancer/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0026679.jpg_e290c5c2-aa86-4c71-bfa2-d89cce0f4f4c.jpg',
#  ...]

# %%
lesion_list_new = [os.path.basename(os.path.dirname(os.path.dirname(y))) for y in glob(os.path.join(data_dir_train, '*','output', '*.jpg'))]
lesion_list_new
# Out:
# ['melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  ...]

# %%
dataframe_dict_new = dict(zip(path_list, lesion_list_new))

# %%
df2 = pd.DataFrame(list(dataframe_dict_new.items()),columns = ['Path','Label'])
new_df = original_df.append(df2)

# %%
new_df['Label'].value_counts()
# Out:
# pigmented benign keratosis    962
# melanoma                      938
# actinic keratosis             614
# seborrheic keratosis          577
# squamous cell carcinoma       420
# basal cell carcinoma          376
# nevus                         357
# vascular lesion               139
# dermatofibroma                 95
# Name: Label, dtype: int64

# %% [markdown]
# So, now we have added 500 images to all the classes to maintain some class balance. We can add more images as we want to improve training process.

# %% [markdown]
# #### **Todo**: Train the model on the data created using Augmentor

# %%
batch_size = 32
img_height = 180
img_width = 180

# %% [markdown]
# #### **Todo:** Create a training dataset

# %%
data_dir_train=pathlib.Path("/content/gdrive/MyDrive/cnn/skincancer/Train")
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir_train,
  seed=123,
  validation_split = 0.2,
  subset = "training",
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 6739 files belonging to 9 classes.
# Using 5392 files for training.

# %% [markdown]
# #### **Todo:** Create a validation dataset

# %%
val_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir_train,
  seed=123,
  validation_split = 0.2,
  subset = "validation",
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 6739 files belonging to 9 classes.
# Using 1347 files for validation.

# %% [markdown]
# #### **Todo:** Create your model (make sure to include normalization)

# %%
## your code goes here
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPool2D
num_classes = 9
model = Sequential([ 
                    layers.experimental.preprocessing.Rescaling(1./255, input_shape=(img_height, img_width,3))
      
])
model.add(Conv2D(filters = 32, kernel_size = (5,5),padding = 'Same', 
                 activation ='relu', input_shape = (180, 180, 32)))
model.add(Conv2D(filters = 32, kernel_size = (5,5),padding = 'Same', 
                 activation ='relu'))
model.add(MaxPool2D(pool_size=(2,2)))
model.add(Conv2D(filters = 64, kernel_size = (5,5),padding = 'Same', 
                 activation ='relu'))
model.add(MaxPool2D(pool_size=(2,2)))
model.add(Conv2D(filters = 64, kernel_size = (5,5),padding = 'Same', 
                 activation ='relu'))
model.add(MaxPool2D(pool_size=(2,2)))
model.add(Dropout(0.25))


model.add(Flatten())
model.add(Dense(num_classes, activation = "softmax"))

# %% [markdown]
# #### **Todo:** Compile your model (Choose optimizer and loss function appropriately)

# %%
## your code goes here
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %% [markdown]
# #### **Todo:**  Train your model

# %%
epochs = 50
## Your code goes here, use 50 epochs.
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/50
# 169/169 [==============================] - 35s 200ms/step - loss: 1.7123 - accuracy: 0.3531 - val_loss: 1.5945 - val_accuracy: 0.3890
# Epoch 2/50
# 169/169 [==============================] - 34s 196ms/step - loss: 1.5483 - accuracy: 0.4049 - val_loss: 1.5188 - val_accuracy: 0.4410
# Epoch 3/50
# 169/169 [==============================] - 33s 190ms/step - loss: 1.4809 - accuracy: 0.4284 - val_loss: 1.4687 - val_accuracy: 0.4358
# Epoch 4/50
# 169/169 [==============================] - 33s 190ms/step - loss: 1.3730 - accuracy: 0.4722 - val_loss: 1.3382 - val_accuracy: 0.4826
# Epoch 5/50
# 169/169 [==============================] - 35s 199ms/step - loss: 1.2177 - accuracy: 0.5423 - val_loss: 1.2280 - val_accuracy: 0.5531
# Epoch 6/50
# 169/169 [==============================] - 33s 190ms/step - loss: 1.0668 - accuracy: 0.6033 - val_loss: 1.1351 - val_accuracy: 0.6288
# Epoch 7/50
# 169/169 [==============================] - 33s 191ms/step - loss: 0.9059 - accuracy: 0.6686 - val_loss: 1.1634 - val_accuracy: 0.6177
# Epoch 8/50
# 169/169 [==============================] - 33s 190ms/step - loss: 0.8368 - accuracy: 0.7014 - val_loss: 1.0439 - val_accuracy: 0.6540
# Epoch 9/50
# 169/169 [==============================] - 33s 191ms/step - loss: 0.7145 - accuracy: 0.7379 - val_loss: 1.0059 - val_accuracy: 0.6726
# Epoch 10/50
# 169/169 [==============================] - 33s 190ms/step - loss: 0.6369 - accuracy: 0.7693 - val_loss: 1.3752 - val_accuracy: 0.6437
# Epoch 11/50
# 169/169 [==============================] - 34s 198ms/step - loss: 0.5840 - accuracy: 0.7925 - val_loss: 0.9267 - val_accuracy: 0.7001
# Epoch 12/50
# 169/169 [==============================] - 33s 191ms/step - loss: 0.4687 - accuracy: 0.8361 - val_loss: 1.0660 - val_accuracy: 0.7134
# Epoch 13/50
# 169/169 [==============================] - 34s 194ms/step - loss: 0.4358 - accuracy: 0.8409 - val_loss: 1.0368 - val_accuracy: 0.7298
# Epoch 14/50
# 169/169 [==============================] - 33s 191ms/step - loss: 0.4078 - accuracy: 0.8550 - val_loss: 1.0295 - val_accuracy: 0.7520
# Epoch 15/50
# 169/169 [==============================] - 33s 189ms/step - loss: 0.3889 - accuracy: 0.8605 - val_loss: 1.2659 - val_accuracy: 0.7008
# Epoch 16/50
# 169/169 [==============================] - 33s 189ms/step - loss: 0.3462 - accuracy: 0.8783 - val_loss: 0.9258 - val_accuracy: 0.7543
# Epoch 17/50
# 169/169 [==============================] - 33s 188ms/step - loss: 0.3343 - accuracy: 0.8789 - val_loss: 0.8716 - val_accuracy: 0.7847
# Epoch 18/50
# 169/169 [==============================] - 34s 189ms/step - loss: 0.3637 - accuracy: 0.8754 - val_loss: 0.9616 - val_accuracy: 0.7439
# Epoch 19/50
# 169/169 [==============================] - 33s 188ms/step - loss: 0.2835 - accuracy: 0.9026 - val_loss: 1.1132 - val_accuracy: 0.7721
# Epoch 20/50
# 169/169 [==============================] - 33s 189ms/step - loss: 0.3027 - accuracy: 0.8952 - val_loss: 1.1739 - val_accuracy: 0.7654
# Epoch 21/50
# 169/169 [==============================] - 33s 190ms/step - loss: 0.2804 - accuracy: 0.8987 - val_loss: 1.0943 - val_accuracy: 0.7743
# Epoch 22/50
# 169/169 [==============================] - 33s 189ms/step - loss: 0.3111 - accuracy: 0.8982 - val_loss: 1.0817 - val_accuracy: 0.7921
# Epoch 23/50
# 169/169 [==============================] - 33s 189ms/step - loss: 0.2431 - accuracy: 0.9136 - val_loss: 1.0272 - val_accuracy: 0.7832
# Epoch 24/50
# 169/169 [==============================] - 34s 195ms/step - loss: 0.2637 - accuracy: 0.9084 - val_loss: 1.0707 - val_accuracy: 0.7676
# Epoch 25/50
# 169/169 [==============================] - 33s 189ms/step - loss: 0.2339 - accuracy: 0.9204 - val_loss: 1.2935 - val_accuracy: 0.7439
# Epoch 26/50
# 169/169 [==============================] - 33s 188ms/step - loss: 0.2422 - accuracy: 0.9232 - val_loss: 1.0930 - val_accuracy: 0.7803
# Epoch 27/50
# 169/169 [==============================] - 33s 187ms/step - loss: 0.2285 - accuracy: 0.9251 - val_loss: 1.1322 - val_accuracy: 0.7929
# Epoch 28/50
# 169/169 [==============================] - 33s 189ms/step - loss: 0.2346 - accuracy: 0.9217 - val_loss: 1.3010 - val_accuracy: 0.7795
# Epoch 29/50
# 169/169 [==============================] - 33s 188ms/step - loss: 0.2416 - accuracy: 0.9186 - val_loss: 1.0521 - val_accuracy: 0.7906
# Epoch 30/50
# 169/169 [==============================] - 33s 188ms/step - loss: 0.2526 - accuracy: 0.9145 - val_loss: 1.2157 - val_accuracy: 0.7832
# Epoch 31/50
# 169/169 [==============================] - 34s 195ms/step - loss: 0.2223 - accuracy: 0.9245 - val_loss: 1.0957 - val_accuracy: 0.7780
# Epoch 32/50
# 169/169 [==============================] - 33s 189ms/step - loss: 0.1891 - accuracy: 0.9369 - val_loss: 1.0823 - val_accuracy: 0.7847
# Epoch 33/50
# 169/169 [==============================] - 33s 188ms/step - loss: 0.2027 - accuracy: 0.9271 - val_loss: 1.1860 - val_accuracy: 0.7751
# Epoch 34/50
# 169/169 [==============================] - 33s 188ms/step - loss: 0.2114 - accuracy: 0.9275 - val_loss: 1.2154 - val_accuracy: 0.7795
# Epoch 35/50
# 169/169 [==============================] - 33s 188ms/step - loss: 0.1994 - accuracy: 0.9390 - val_loss: 1.1257 - val_accuracy: 0.7699
# Epoch 36/50
# 169/169 [==============================] - 33s 188ms/step - loss: 0.1880 - accuracy: 0.9360 - val_loss: 1.0244 - val_accuracy: 0.7788
# Epoch 37/50
# 169/169 [==============================] - 33s 188ms/step - loss: 0.1981 - accuracy: 0.9338 - val_loss: 1.2642 - val_accuracy: 0.7854
# Epoch 38/50
# 169/169 [==============================] - 34s 195ms/step - loss: 0.2245 - accuracy: 0.9249 - val_loss: 1.0916 - val_accuracy: 0.7817
# Epoch 39/50
# 169/169 [==============================] - 33s 190ms/step - loss: 0.2289 - accuracy: 0.9277 - val_loss: 1.4057 - val_accuracy: 0.7721
# Epoch 40/50
# 169/169 [==============================] - 33s 188ms/step - loss: 0.1885 - accuracy: 0.9384 - val_loss: 1.2723 - val_accuracy: 0.7773
# Epoch 41/50
# 169/169 [==============================] - 33s 188ms/step - loss: 0.1664 - accuracy: 0.9445 - val_loss: 1.2238 - val_accuracy: 0.7780
# Epoch 42/50
# 169/169 [==============================] - 33s 188ms/step - loss: 0.1687 - accuracy: 0.9453 - val_loss: 1.2699 - val_accuracy: 0.7854
# Epoch 43/50
# 169/169 [==============================] - 33s 188ms/step - loss: 0.1923 - accuracy: 0.9355 - val_loss: 1.2202 - val_accuracy: 0.7743
# Epoch 44/50
# 169/169 [==============================] - 33s 187ms/step - loss: 0.2008 - accuracy: 0.9305 - val_loss: 1.4178 - val_accuracy: 0.7283
# Epoch 45/50
# 169/169 [==============================] - 34s 190ms/step - loss: 0.1745 - accuracy: 0.9416 - val_loss: 1.5416 - val_accuracy: 0.7439
# Epoch 46/50
# 169/169 [==============================] - 33s 187ms/step - loss: 0.1847 - accuracy: 0.9377 - val_loss: 1.1467 - val_accuracy: 0.7773
# Epoch 47/50
# 169/169 [==============================] - 33s 188ms/step - loss: 0.2156 - accuracy: 0.9277 - val_loss: 1.2162 - val_accuracy: 0.7825
# Epoch 48/50
# 169/169 [==============================] - 33s 188ms/step - loss: 0.1687 - accuracy: 0.9427 - val_loss: 1.3665 - val_accuracy: 0.7899
# Epoch 49/50
# 169/169 [==============================] - 33s 187ms/step - loss: 0.1423 - accuracy: 0.9497 - val_loss: 1.3121 - val_accuracy: 0.7795
# Epoch 50/50
# 169/169 [==============================] - 33s 188ms/step - loss: 0.1557 - accuracy: 0.9466 - val_loss: 1.3800 - val_accuracy: 0.7558

# %% [markdown]
# #### **Todo:**  Visualize the model results

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# #### **Todo:**  Analyze your results here. Did you get rid of underfitting/overfitting? Did class rebalance help?
#
# #### Accuracy of training dataset is 94.66%. validation data is 75.58%
# #### Able to assist the model with overfitting.
